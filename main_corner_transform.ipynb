# %%
import example_loader as el
import gurobipy as gp
import gurobi_utils as gu
import miplib_loader as ml
import numpy as np
import plot_utils as pu
import importlib as il
import dikin_utils as du

# %%
# configure the backend for matplotlib
# this one should allow zoom:
# %matplotlib widget
# to make that work you need: "pip install ipympl" and run "jupyter nbextension enable --py widgetsnbextension"

# this will work without the above dependencies but won't allow zoom
# %matplotlib inline

# this option may work whenever they fix bugs in mpld3
# import mpld3
# mpld3.enable_notebook()

# %%
env = gp.Env(empty=True)
env.setParam("OutputFlag", 0)
env.start()
# Out:
# <gurobipy.Env, Parameter changes: WLSAccessID=(user-defined), WLSSecret=(user-defined), LicenseID=2586148, OutputFlag=0>

# %%
il.reload(el)
il.reload(gu)
il.reload(pu)
il.reload(du)

def find_unimodular(tableau, row_idx, tol):
    # tableau = np.round(tableau / tol)
    tableau = tableau / tol
    U, A2 = du.to_ref_unimodular(tableau)
    
    return U, A2

def get_coeffs(expr: gp.LinExpr, variable):
    s = 0.0
    for i in range(expr.size()):
        if expr.getVar(i).index == variable.index:
            s += expr.getCoeff(i)
    return s

# A function to create cuts given a target point
def add_cut(relaxed: gp.Model, integer_vars, integer_idx, plotter):
    
    if plotter is not None:
        plotter.add_ball(1.2)

    tol = relaxed.params.FeasibilityTol
    all_done = True
    for iv in integer_vars:
        x = iv.X.item()
        if not np.isclose(x, round(x), atol=tol):
            all_done = False
            break
    if all_done:
        return False
    
    variables = relaxed.getVars()  # TODO: pass this in as it's expensive?
    constraints = relaxed.getConstrs()  # wish we didn't have to use this one
    
    def find_variable(index):
        if index < len(variables):  # variables is from model.getVars()
            # handle inverted variables (SCIP and Gurobi both have this silliness)
            match variables[index].VBasis:
                case gp.GRB.SUPERBASIC:
                    raise NotImplementedError("Not yet handling SUPERBASIC") 
                case gp.GRB.NONBASIC_UPPER:
                    return variables[index].UB - variables[index]
                case gp.GRB.NONBASIC_LOWER:
                    return variables[index] - variables[index].LB
                case _:
                    return variables[index]
        # if only gurobi gave us access to their slack variables...
        # instead, we have to solve for it:
        cons_idx = index - len(variables)
        constraint = constraints[cons_idx]
        lhs, sense, rhs = relaxed.getRow(constraint), constraint.Sense, constraint.RHS
        if sense == '<':
            return rhs - lhs
        elif sense == '>':
            return lhs - rhs
        else:
            return 0.0  # Gurobi has slacks on equality constraints, but they must always be 0
        
    basis = gu.read_basis(relaxed)
    tableau, col_to_var_idx, negated_rows = gu.read_tableau(relaxed, basis, extra_rows=0)
    negated_vars = [basis[nr] for nr in negated_rows]

    # the current understanding (from nlhdlr_quadratic.c in SCIP): 
    # negate all columns with variables at status -1
    # and negate all columns match slack variables of type <
    for col, j in enumerate(col_to_var_idx):
        if j < len(variables):
            # print("Var INFO:", variables[j].VarName, "VBasis", variables[j].VBasis, "LB", variables[j].LB, "UB", variables[j].UB)
            if variables[j].VBasis == -2:
                tableau[:, col] = -tableau[:, col]  # might need to be UB - ... ?
            elif variables[j].VBasis == -1:  # not sure what to do with VBasis=-3
                if variables[j].LB != 0.0:
                    print("Warning: LB is nonzero for variable", variables[j].VarName, "LB", variables[j].LB, "UB", variables[j].UB)
        else:
            constraint = constraints[j - len(variables)]
            if constraint.Sense == '>':  # Achterberg said lt and lte are standard; should just need to flip gt
                tableau[:, col] = -tableau[:, col]

    # drop the rows of non-integer variables:
    to_drop = [i for i, b in enumerate(basis) if b not in integer_idx]
    tableau = np.delete(tableau, to_drop, axis=0)  # TODO: don't even bother to read them in
    basis = np.delete(basis, to_drop) # update basis to match tableau

    non_zero_columns = ~np.all(np.abs(tableau) <= tol, axis=0)
    tableau = tableau[:, non_zero_columns]
    col_to_var_idx = col_to_var_idx[non_zero_columns]

    # drop all rows that are non-fractional:
    tol = relaxed.params.IntFeasTol
    # should we also drop rows for integers that are not fractional?
    # to_drop = [i for i, b in enumerate(basis) if np.isclose(x[integer_idx[b]], round(x[integer_idx[b]]), tol)]
    # tableau = np.delete(tableau, to_drop, axis=0)  # TODO: don't even bother to read them in
    # basis = np.delete(basis, to_drop)
    # x_idx = [integer_idx[b] for b in basis]

    xv = [integer_vars[integer_idx[b]].X.item() for i, b in enumerate(basis)]
    to_cut = [(i, b) for i, b in enumerate(basis) if tol < (xv[i] % 1) < 1.0-tol]
    
    cuts = []
    for row, base in to_cut:
        # print("Row", row, "Base", base, "X", x, "Slack", constraints[row].Slack)
        # if not np.isclose(constraints[row].Slack, 0.0, atol=tol):
        #     tableau[row] = -tableau[row]
        if np.all(np.isclose(tableau[row], 0.0, atol=tol)):
            print("Warning! Empty row", row)
            continue
        elif np.all(tableau[row] >= -tol):
            # find_variable(base).LB = np.ceil(x)
            cuts.append(find_variable(base) <= np.ceil(x))
        elif np.all(tableau[row] <= tol):
            cuts.append(find_variable(base) >= np.floor(x))

    if len(cuts) > 0:
        print("Added simple bound cuts:", len(cuts))
        for cut in cuts: 
            bc = relaxed.addConstr(cut)
            if plotter is not None:
                relaxed.update()
                plotter.add_constraint(bc)
        return True
            
    col_vars = [find_variable(c) for c in col_to_var_idx]
    u, tableau2 = find_unimodular(tableau, to_cut[0][0], tol)
    xv2 = u @ (np.array(xv) / tol)
    # ui = np.linalg.inv(u)
    # assert ui == u

    for row, base in to_cut:
        x = xv2[row]
        if np.all(np.isclose(tableau2[row], 0.0, atol=tol)):
            print("Warning! Empty row", row)
            continue  # TODO: I don't really want this to be possible
        elif np.all(tableau2[row] >= -tol):
            # does it work when all variables are basis variables?
            # do I need to transform the variables that correspond to columns in my transformed tableau?
            # or to rows? the transformed tableau should give different RHS values, no?
            # cuts.append((it2[row] @ col_vars >= np.ceil(x) - x, 'xkcd:teal'))
            # cuts.append(((u.T @ tableau[row]).T @ col_vars >= np.ceil(x) - x, 'xkcd:teal'))
            # cuts.append((x - tableau2[row] @ col_vars <= np.floor(x), 'xkcd:teal'))
            # cuts.append((x + tableau2[row] @ col_vars >= np.ceil(x), 'xkcd:berry'))
            # oversimplified for the moment:
            # if relaxed.ModelSense != gp.GRB.MAXIMIZE:
            cuts.append((x - tableau2[row] @ col_vars <= np.floor(x), 'xkcd:teal'))
            # else:
            # cuts.append((x + tableau2[row] @ col_vars >= np.ceil(x), 'xkcd:berry'))
        elif np.all(tableau2[row] <= tol):
            # if relaxed.ModelSense != gp.GRB.MAXIMIZE:
            cuts.append((x + tableau2[row] @ col_vars >= np.ceil(x), 'xkcd:orange'))
            # else:
            cuts.append((x - tableau2[row] @ col_vars <= np.floor(x), 'xkcd:brown'))
            # elif np.all(tableau2[row] <= tol):
            # cuts.append((x + tableau2[row] @ col_vars >= np.ceil(x), 'xkcd:berry'))
            # cuts.append((x - tableau2[row] @ col_vars <= np.floor(x), 'xkcd:teal'))
        
        if False:  # do the split cut
            points = []
            for col, ray in enumerate(tableau.T):
                rr = ray[row]
                # if row in negated_rows:
                #     rr = -rr
                if np.isclose(rr, 0, atol=tol):
                    continue
                scale = -rr / (x % 1) if rr < 0 else rr / (1-(x % 1))
                # print("SCALE", scale, x, rr)
                # point = basis_corner.copy()
                # point[basis] += scale * ray[:-1]
                # point[r] += scale * ray[-1]
                # print("INFO", row, col, base, x, ray, scale)

                points.append((find_variable(col_to_var_idx[col]), scale))
            if points:
                summed_terms = gp.quicksum(nrm * v for v, nrm in points)
                cuts.append((summed_terms >= 1, 'xkcd:pink'))

    if len(cuts) > 0:
        print("Added simple bound cuts after transform:", len(cuts))
        for cut, color in cuts: 
            bc = relaxed.addConstr(cut)
            if plotter is not None:
                relaxed.update()
                plotter.add_constraint(bc, color)
        return True

    raise NotImplementedError("No cuts found")

def run_cuts_to_relaxed_sol(instances, loops=8, graph_2D_3D=True):
    for instance in instances:
        model: gp.Model = instance.as_gurobi_model()
        print("Running model:", model.ModelName)
        model.params.LogToConsole = 0
        model.update()
        plotter = pu.create(model) if graph_2D_3D else None
        # gu.standardize_gt_to_lt(model)
        int_vars, int_idx = gu.relax_int_or_bin_to_continuous(model)
        for i in range(loops):
            model.optimize()
            if model.Status != gp.GRB.OPTIMAL:
                print("   FAILED! Status:", model.Status)
                break

            print("   Loop:", i+1, ", Relaxed score:", model.getObjective().getValue())
            if not add_cut(model, int_vars, int_idx, plotter):
                print("   Done! All constraints met.")
                break

        print("   Known best score:", instance.score if instance.known_optimum else "unknown")    
        if plotter is not None:
            plotter.render()

# test the cuts on simple examples (5-8 don't draw all cuts correctly): fails: 1, 3
run_cuts_to_relaxed_sol(list(el.get_instances(env).values())[0:1], loops=2)
# Out:
# Running model: 2D from bottom
#    Relaxed 2 variables on 2D from bottom
#    Loop: 1 , Relaxed score: 2.3333333333333335
# Added simple bound cuts: 1
#    Loop: 2 , Relaxed score: 2.0
# Added simple bound cuts after transform: 1
#    Known best score: 2

# %%
miplib_instances = ml.get_instances()
miplib_subset = [miplib_instances['air05'], miplib_instances['markshare2']]  # mas76
run_cuts_to_relaxed_sol(miplib_subset[0:1])

# %%
import jsplib_loader as jl
jsplib_instances = jl.get_instances()
jsplib_subset = [jsplib_instances['abz4']]
run_cuts_to_relaxed_sol(jsplib_subset, loops=500)
# Out:
# Set parameter AggFill to value 10
# Set parameter GomoryPasses to value 1
# Running model: abz4
# Set parameter LogToConsole to value 0
#    Relaxed 216 variables on abz4
#    Loop: 1 , Relaxed score: 505.0
# Added simple bound cuts after transform: 52
#    Loop: 2 , Relaxed score: 508.2230396003054
# Added simple bound cuts after transform: 43
#    Loop: 3 , Relaxed score: 589.1404202664414
# Added simple bound cuts after transform: 42
#    Loop: 4 , Relaxed score: 593.3628174332823
# Added simple bound cuts after transform: 43
#    Loop: 5 , Relaxed score: 602.5184494754415
# Added simple bound cuts after transform: 44
#    Loop: 6 , Relaxed score: 604.9856597094661
# Added simple bound cuts after transform: 44
#    Loop: 7 , Relaxed score: 607.767811468907
# Added simple bound cuts after transform: 45
#    Loop: 8 , Relaxed score: 608.7895680965971
# Added simple bound cuts after transform: 41
#    Loop: 9 , Relaxed score: 608.9012033669532
# Added simple bound cuts after transform: 39
#    Loop: 10 , Relaxed score: 610.0001369521027
# Added simple bound cuts after transform: 38
#    Loop: 11 , Relaxed score: 610.0118043756534
# Added simple bound cuts after transform: 40
#    Loop: 12 , Relaxed score: 610.0163086922736
# Added simple bound cuts after transform: 27
#    Loop: 13 , Relaxed score: 610.0163220153355
# Added simple bound cuts after transform: 30
#    Loop: 14 , Relaxed score: 610.0163979458118
# Added simple bound cuts after transform: 40
#    Loop: 15 , Relaxed score: 610.0310257240636
# Added simple bound cuts after transform: 42
#    Loop: 16 , Relaxed score: 610.0377161710703
# Added simple bound cuts after transform: 39
#    Loop: 17 , Relaxed score: 610.0665602077587
# Added simple bound cuts after transform: 42
#    Loop: 18 , Relaxed score: 610.2161993157042
# Added simple bound cuts after transform: 45
#    Loop: 19 , Relaxed score: 610.2468651330422
# Added simple bound cuts after transform: 44
#    Loop: 20 , Relaxed score: 610.28795820272
# Added simple bound cuts after transform: 38
#    Loop: 21 , Relaxed score: 610.3160735513766
# Added simple bound cuts after transform: 35
#    Loop: 22 , Relaxed score: 610.3168069118518
# Added simple bound cuts after transform: 36
#    Loop: 23 , Relaxed score: 610.3171813635458
# Added simple bound cuts after transform: 37
#    Loop: 24 , Relaxed score: 610.3205421163212
# Added simple bound cuts after transform: 34
#    Loop: 25 , Relaxed score: 610.3207225337832
# Added simple bound cuts after transform: 38
#    Loop: 26 , Relaxed score: 610.3213359212306
# Added simple bound cuts after transform: 42
#    Loop: 27 , Relaxed score: 610.3265791643304
# Added simple bound cuts after transform: 41
#    Loop: 28 , Relaxed score: 610.3403042745763
# Added simple bound cuts after transform: 44
#    Loop: 29 , Relaxed score: 610.3423027591539
# Added simple bound cuts after transform: 41
#    Loop: 30 , Relaxed score: 610.3431716115681
# Added simple bound cuts after transform: 42
#    Loop: 31 , Relaxed score: 610.346423257379
# Added simple bound cuts after transform: 42
#    Loop: 32 , Relaxed score: 610.3480414987861
# Added simple bound cuts after transform: 42
#    Loop: 33 , Relaxed score: 610.3523839086124
# Added simple bound cuts after transform: 43
#    Loop: 34 , Relaxed score: 610.3660218212998
# Added simple bound cuts after transform: 41
#    Loop: 35 , Relaxed score: 610.3679233647244
# Added simple bound cuts after transform: 45
#    Loop: 36 , Relaxed score: 610.3733507004708
# Added simple bound cuts after transform: 46
#    Loop: 37 , Relaxed score: 610.3812361829922
# Added simple bound cuts after transform: 45
#    Loop: 38 , Relaxed score: 610.3868983966408
# Added simple bound cuts after transform: 44
#    Loop: 39 , Relaxed score: 610.3940000527408
# Added simple bound cuts after transform: 43
#    Loop: 40 , Relaxed score: 610.4042961616933
# Added simple bound cuts after transform: 46
#    Loop: 41 , Relaxed score: 610.4109814097086
# Added simple bound cuts after transform: 49
#    Loop: 42 , Relaxed score: 610.4167882713922
# Added simple bound cuts after transform: 46
#    Loop: 43 , Relaxed score: 610.4194183520201
# Added simple bound cuts after transform: 45
#    Loop: 44 , Relaxed score: 610.4231687999458
# Added simple bound cuts after transform: 47
#    Loop: 45 , Relaxed score: 610.4278319692987
# Added simple bound cuts after transform: 45
#    Loop: 46 , Relaxed score: 611.4019271421364
# Added simple bound cuts after transform: 36
#    Loop: 47 , Relaxed score: 612.9912408891988
# Added simple bound cuts after transform: 39
#    Loop: 48 , Relaxed score: 613.2279692518265
# Added simple bound cuts after transform: 33
#    Loop: 49 , Relaxed score: 613.6508136473763
# Added simple bound cuts after transform: 42
#    Loop: 50 , Relaxed score: 613.8656704677458
# Added simple bound cuts after transform: 45
#    Loop: 51 , Relaxed score: 614.291360178571
# Added simple bound cuts after transform: 50
#    Loop: 52 , Relaxed score: 614.5853016075836
# Added simple bound cuts after transform: 45
#    Loop: 53 , Relaxed score: 614.7460270500493
# Added simple bound cuts after transform: 38
#    Loop: 54 , Relaxed score: 614.8067070378925
# Added simple bound cuts after transform: 44
#    Loop: 55 , Relaxed score: 614.8332289458095
# Added simple bound cuts after transform: 44
#    Loop: 56 , Relaxed score: 614.8360597870853
# Added simple bound cuts after transform: 46
#    Loop: 57 , Relaxed score: 614.8540785320688
# Added simple bound cuts after transform: 47
#    Loop: 58 , Relaxed score: 614.8574449671426
# Added simple bound cuts after transform: 46
#    Loop: 59 , Relaxed score: 614.8600068658369
# Added simple bound cuts after transform: 47
#    Loop: 60 , Relaxed score: 614.8673214187401
# Added simple bound cuts after transform: 42
#    Loop: 61 , Relaxed score: 614.8736070598349
# Added simple bound cuts after transform: 42
#    Loop: 62 , Relaxed score: 614.8738146878827
# Added simple bound cuts after transform: 41
#    Loop: 63 , Relaxed score: 614.8738890244271
# Added simple bound cuts after transform: 45
#    Loop: 64 , Relaxed score: 614.8741160528992
# Added simple bound cuts after transform: 46
#    Loop: 65 , Relaxed score: 614.8742767531222
# Added simple bound cuts after transform: 46
#    Loop: 66 , Relaxed score: 614.874330759288
# Added simple bound cuts after transform: 44
#    Loop: 67 , Relaxed score: 614.8786589860617
# Added simple bound cuts after transform: 38
#    Loop: 68 , Relaxed score: 614.8789004338083
# Added simple bound cuts after transform: 41
#    Loop: 69 , Relaxed score: 614.8796304485317
# Added simple bound cuts after transform: 42
#    Loop: 70 , Relaxed score: 614.8831885793453
# Added simple bound cuts after transform: 40
#    Loop: 71 , Relaxed score: 614.8834248508356
# Added simple bound cuts after transform: 37
#    Loop: 72 , Relaxed score: 614.8842181342811
# Added simple bound cuts after transform: 44
#    Loop: 73 , Relaxed score: 614.8846702636521
# Added simple bound cuts after transform: 40
#    Loop: 74 , Relaxed score: 614.8849267139898
# Added simple bound cuts after transform: 42
#    Loop: 75 , Relaxed score: 614.8857857450433
# Added simple bound cuts after transform: 43
#    Loop: 76 , Relaxed score: 614.8862431782982
# Added simple bound cuts after transform: 44
#    Loop: 77 , Relaxed score: 614.8869626154668
# Added simple bound cuts after transform: 38
#    Loop: 78 , Relaxed score: 614.8871801615622
# Added simple bound cuts after transform: 42
#    Loop: 79 , Relaxed score: 614.8875637214693
# Added simple bound cuts after transform: 43
#    Loop: 80 , Relaxed score: 614.8879823367317
# Added simple bound cuts after transform: 47
#    Loop: 81 , Relaxed score: 614.8881323827578
# Added simple bound cuts after transform: 43
#    Loop: 82 , Relaxed score: 614.8893692362517
# Added simple bound cuts after transform: 44
#    Loop: 83 , Relaxed score: 614.8930283395105
# Added simple bound cuts after transform: 41
#    Loop: 84 , Relaxed score: 614.8932927933197
# Added simple bound cuts after transform: 42
#    Loop: 85 , Relaxed score: 614.8942382515748
# Added simple bound cuts after transform: 43
#    Loop: 86 , Relaxed score: 614.8949597724376
# Added simple bound cuts after transform: 42
#    Loop: 87 , Relaxed score: 614.8951642718645
# Added simple bound cuts after transform: 39
#    Loop: 88 , Relaxed score: 614.8954101369236
# Added simple bound cuts after transform: 39
#    Loop: 89 , Relaxed score: 614.8956317524339
# Added simple bound cuts after transform: 38
#    Loop: 90 , Relaxed score: 614.8959156142736
# Added simple bound cuts after transform: 39
#    Loop: 91 , Relaxed score: 614.8959869833376
# Added simple bound cuts after transform: 37
#    Loop: 92 , Relaxed score: 614.8973225482628
# Added simple bound cuts after transform: 38
#    Loop: 93 , Relaxed score: 614.8976600145272
# Added simple bound cuts after transform: 43
#    Loop: 94 , Relaxed score: 614.8978023264253
# Added simple bound cuts after transform: 41
#    Loop: 95 , Relaxed score: 614.8978783388117
# Added simple bound cuts after transform: 42
#    Loop: 96 , Relaxed score: 614.8979784197696
# Added simple bound cuts after transform: 43
#    Loop: 97 , Relaxed score: 614.8980133119942
# Added simple bound cuts after transform: 40
#    Loop: 98 , Relaxed score: 614.8980601932583
# Added simple bound cuts after transform: 40
#    Loop: 99 , Relaxed score: 614.8980787905625
# Added simple bound cuts after transform: 43
#    Loop: 100 , Relaxed score: 614.8980860373226
# Added simple bound cuts after transform: 38
#    Loop: 101 , Relaxed score: 614.8980876329097
# Added simple bound cuts after transform: 38
#    Loop: 102 , Relaxed score: 614.8980916933014
# Added simple bound cuts after transform: 40
#    Loop: 103 , Relaxed score: 614.8981007186352
# Added simple bound cuts after transform: 40
#    Loop: 104 , Relaxed score: 614.8981086499723
# Added simple bound cuts after transform: 40
#    Loop: 105 , Relaxed score: 614.8981353929793
# Added simple bound cuts after transform: 40
#    Loop: 106 , Relaxed score: 614.898141736166
# Added simple bound cuts after transform: 38
#    Loop: 107 , Relaxed score: 614.8981504996511
# Added simple bound cuts after transform: 37
#    Loop: 108 , Relaxed score: 614.8981685642256
# Added simple bound cuts after transform: 36
#    Loop: 109 , Relaxed score: 614.8982022620061
# Added simple bound cuts after transform: 33
#    Loop: 110 , Relaxed score: 614.8982070630547
# Added simple bound cuts after transform: 37
#    Loop: 111 , Relaxed score: 614.8982097513343
# Added simple bound cuts after transform: 38
#    Loop: 112 , Relaxed score: 614.8982173895683
# Added simple bound cuts after transform: 35
#    Loop: 113 , Relaxed score: 614.8982133782486
# Added simple bound cuts after transform: 32
#    Loop: 114 , Relaxed score: 614.8982139284183
# Added simple bound cuts after transform: 34
#    Loop: 115 , Relaxed score: 614.8982145120763
# Added simple bound cuts after transform: 33
#    Loop: 116 , Relaxed score: 614.8982214623302
# Added simple bound cuts after transform: 39
#    Loop: 117 , Relaxed score: 614.8982152879526
# Added simple bound cuts after transform: 37
#    Loop: 118 , Relaxed score: 614.8982154471626
# Added simple bound cuts after transform: 34
#    Loop: 119 , Relaxed score: 614.8982156992323
# Added simple bound cuts after transform: 37
#    Loop: 120 , Relaxed score: 614.8982156638729
# Added simple bound cuts after transform: 26
#    Loop: 121 , Relaxed score: 614.8982168682381
# Added simple bound cuts after transform: 26
#    Loop: 122 , Relaxed score: 614.8982174343494
# Added simple bound cuts after transform: 31
#    Loop: 123 , Relaxed score: 614.898217186219
# Added simple bound cuts after transform: 39
#    Loop: 124 , Relaxed score: 614.8982175665509
# Added simple bound cuts after transform: 37
#    Loop: 125 , Relaxed score: 614.8982170914263
# Added simple bound cuts after transform: 35
#    Loop: 126 , Relaxed score: 614.8982179072282
# Added simple bound cuts after transform: 34
#    Loop: 127 , Relaxed score: 614.8982170036097
# Added simple bound cuts after transform: 37
#    Loop: 128 , Relaxed score: 614.8982173030514
# Added simple bound cuts after transform: 38
#    Loop: 129 , Relaxed score: 614.8982174252806
# Added simple bound cuts after transform: 34
#    Loop: 130 , Relaxed score: 614.8982168684456
# Added simple bound cuts after transform: 33
#    Loop: 131 , Relaxed score: 614.8982177167609
# Added simple bound cuts after transform: 32
#    Loop: 132 , Relaxed score: 614.8982182973042
# Added simple bound cuts after transform: 29
#    Loop: 133 , Relaxed score: 614.8982205522884
# Added simple bound cuts after transform: 37
#    Loop: 134 , Relaxed score: 614.8982225272927
# Added simple bound cuts after transform: 30
#    Loop: 135 , Relaxed score: 614.8982232958871
# Added simple bound cuts after transform: 33
#    Loop: 136 , Relaxed score: 614.898231863074
# Added simple bound cuts after transform: 37
#    Loop: 137 , Relaxed score: 614.8982321341259
# Added simple bound cuts after transform: 30
#    Loop: 138 , Relaxed score: 614.8982317853906
# Added simple bound cuts after transform: 31
#    Loop: 139 , Relaxed score: 614.898234283302
# Added simple bound cuts after transform: 32
#    Loop: 140 , Relaxed score: 614.8982360437908
# Added simple bound cuts after transform: 33
#    Loop: 141 , Relaxed score: 614.8982304324012
# Added simple bound cuts after transform: 33
#    Loop: 142 , Relaxed score: 614.8982331830085
# Added simple bound cuts after transform: 32
#    Loop: 143 , Relaxed score: 614.8982348948014
# Added simple bound cuts after transform: 32
#    Loop: 144 , Relaxed score: 614.8982366033728
# Added simple bound cuts after transform: 31
#    Loop: 145 , Relaxed score: 614.8982368645894
# Added simple bound cuts after transform: 31
#    Loop: 146 , Relaxed score: 614.8982369934813
# Added simple bound cuts after transform: 36
#    Loop: 147 , Relaxed score: 614.8982370668338
# Added simple bound cuts after transform: 38
#    Loop: 148 , Relaxed score: 614.8982370760194
# Added simple bound cuts after transform: 32
#    Loop: 149 , Relaxed score: 614.898239401564
# Added simple bound cuts after transform: 33
#    Loop: 150 , Relaxed score: 614.8982409388619
# Added simple bound cuts after transform: 35
#    Loop: 151 , Relaxed score: 614.8982413808012
# Added simple bound cuts after transform: 30
#    Loop: 152 , Relaxed score: 614.8982431977054
# Added simple bound cuts after transform: 31
#    Loop: 153 , Relaxed score: 614.8982426208961
# Added simple bound cuts after transform: 41
#    Loop: 154 , Relaxed score: 614.898244500072
# Added simple bound cuts after transform: 40
#    Loop: 155 , Relaxed score: 614.8982457880339
# Added simple bound cuts after transform: 37
#    Loop: 156 , Relaxed score: 614.8982450709017
# Added simple bound cuts after transform: 37
#    Loop: 157 , Relaxed score: 614.8982455772714
# Added simple bound cuts after transform: 38
#    Loop: 158 , Relaxed score: 614.898242221397
# Added simple bound cuts after transform: 37
#    Loop: 159 , Relaxed score: 614.8982409371877
# Added simple bound cuts after transform: 37
#    Loop: 160 , Relaxed score: 614.898242094614
# Added simple bound cuts after transform: 34
#    Loop: 161 , Relaxed score: 614.8982430936773
# Added simple bound cuts after transform: 33
#    Loop: 162 , Relaxed score: 614.8982433510281
# Added simple bound cuts after transform: 33
#    Loop: 163 , Relaxed score: 614.8982434139174
# Added simple bound cuts after transform: 31
#    Loop: 164 , Relaxed score: 614.8982434761989
# Added simple bound cuts after transform: 31
#    Loop: 165 , Relaxed score: 614.898244291456
# Added simple bound cuts after transform: 32
#    Loop: 166 , Relaxed score: 614.8982440649014
# Added simple bound cuts after transform: 33
#    Loop: 167 , Relaxed score: 614.898240637921
# Added simple bound cuts after transform: 36
#    Loop: 168 , Relaxed score: 614.8982407420654
# Added simple bound cuts after transform: 36
#    Loop: 169 , Relaxed score: 614.8982419023391
# Added simple bound cuts after transform: 36
#    Loop: 170 , Relaxed score: 614.8982420851626
# Added simple bound cuts after transform: 37
#    Loop: 171 , Relaxed score: 614.8982439674902
# Added simple bound cuts after transform: 31
#    Loop: 172 , Relaxed score: 614.898250144915
# Added simple bound cuts after transform: 24
#    Loop: 173 , Relaxed score: 614.8982454168121
# Added simple bound cuts after transform: 23
#    Loop: 174 , Relaxed score: 614.898245255953
# Added simple bound cuts after transform: 22
#    Loop: 175 , Relaxed score: 614.8982434575514
# Added simple bound cuts after transform: 23
#    Loop: 176 , Relaxed score: 614.8982450549609
# Added simple bound cuts after transform: 24
#    Loop: 177 , Relaxed score: 614.8982456749137
# Added simple bound cuts after transform: 22
#    Loop: 178 , Relaxed score: 614.8982460163963
# Added simple bound cuts after transform: 25
#    Loop: 179 , Relaxed score: 614.898234173405
# Added simple bound cuts after transform: 34
#    Loop: 180 , Relaxed score: 614.8982343373696
# Added simple bound cuts after transform: 32
#    Loop: 181 , Relaxed score: 614.8982353155403
# Added simple bound cuts after transform: 31
#    Loop: 182 , Relaxed score: 614.898237494246
# Added simple bound cuts after transform: 30
#    Loop: 183 , Relaxed score: 614.898238956371
# Added simple bound cuts after transform: 31
#    Loop: 184 , Relaxed score: 614.8982429947894
# Added simple bound cuts after transform: 29
#    Loop: 185 , Relaxed score: 614.8982433276959
# Added simple bound cuts after transform: 30
#    Loop: 186 , Relaxed score: 614.8982433940251
# Added simple bound cuts after transform: 32
#    Loop: 187 , Relaxed score: 614.8982458813912
# Added simple bound cuts after transform: 30
#    Loop: 188 , Relaxed score: 614.8982421192761
# Added simple bound cuts after transform: 37
#    Loop: 189 , Relaxed score: 614.8982435049322
# Added simple bound cuts after transform: 32
#    Loop: 190 , Relaxed score: 614.8982466302305
# Added simple bound cuts after transform: 31
#    Loop: 191 , Relaxed score: 614.8982481682069
# Added simple bound cuts after transform: 32
#    Loop: 192 , Relaxed score: 614.898248844094
# Added simple bound cuts after transform: 31
#    Loop: 193 , Relaxed score: 614.8982491163715
# Added simple bound cuts after transform: 32
#    Loop: 194 , Relaxed score: 614.8982490496917
# Added simple bound cuts after transform: 32
#    Loop: 195 , Relaxed score: 614.8982492455835
# Added simple bound cuts after transform: 33
#    Loop: 196 , Relaxed score: 614.8982465849973
# Added simple bound cuts after transform: 32
#    Loop: 197 , Relaxed score: 614.8982486294731
# Added simple bound cuts after transform: 32
#    Loop: 198 , Relaxed score: 614.8982503848374
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 4
#       2 jsplib_instances = jl.get_instances()
#       3 jsplib_subset = [jsplib_instances['abz4']]
# ----> 4 run_cuts_to_relaxed_sol(jsplib_subset, loops=500)
#
# Cell In[73], line 230, in run_cuts_to_relaxed_sol(instances, loops, graph_2D_3D)
#     227     break
#     229 print("   Loop:", i+1, ", Relaxed score:", model.getObjective().getValue())
# --> 230 if not add_cut(model, int_vars, int_idx, plotter):
#     231     print("   Done! All constraints met.")
#     232     break
#
# Cell In[73], line 63, in add_cut(relaxed, integer_vars, integer_idx, plotter)
#      60         return 0.0  # Gurobi has slacks on equality constraints, but they must always be 0
#      62 basis = gu.read_basis(relaxed)
# ---> 63 tableau, col_to_var_idx, negated_rows = gu.read_tableau(relaxed, basis, extra_rows=0)
#      64 negated_vars = [basis[nr] for nr in negated_rows]
#      66 # the current understanding (from nlhdlr_quadratic.c in SCIP):
#      67 # negate all columns with variables at status -1
#      68 # and negate all columns match slack variables of type <
#
# File ~/Documents/Research/intersection_cuts/gurobi_utils.py:58, in read_tableau(m, basis, extra_rows, remove_basis_cols)
#      55 assert ptr != 0
#      56 for row in range(rows):
#      57     # TODO: pass in a list of variables to skip so we don't read unnecessary rows
# ---> 58     err = _gurobi_dll.GRBBinvRowi(ptr, row, data)
#      59     assert err == 0
#      60     indexes = data.ind[:data.len]
#
# KeyboardInterrupt:
